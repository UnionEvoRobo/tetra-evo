# %%
# Setup
import plot_utils_new as plot

# %% [markdown]
# # Plot Fitness vs. Evaluations for One or More Runs

# %%
csv_paths: str = "latest_run" # Use "latest_run" or path-like string to a run.csv file.
plot.single_run(csv_paths)
